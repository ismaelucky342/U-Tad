# %%
import os 
os.environ["KERAS_BACKEND"] = "jax"

# %%
import keras
from keras import layers
from keras import Sequential
from keras.datasets import california_housing
from sklearn.preprocessing import StandardScaler

# %%
#tupla, con parentesis que sino es una guarrada
(train_data, train_targets), (test_data, test_targets) = california_housing.load_data(version="small")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/california_housing.npz
# 743530/743530 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step

# %%
train_data.shape
# Out:
# (480, 8)

# %%
test_data.shape
# Out:
# (120, 8)

# %%
train_targets.min()
# Out:
# 60000.0

# %% [markdown]
# # Normalización de Datos

# %%
mu = train_data.mean(axis=0)
s = train_data.std(axis=0)
x_train = (train_data - mu) / s
x_test = (test_data - mu) / s

# %%
y_train = train_targets / 1e5
y_test = test_targets / 1e5

# %% [markdown]
# # El modelo

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"), 
    layers.Dense(64, activation="relu"), 
    layers.Dense(1, activation="linear")
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)
# Out:
# INFO:2025-10-27 10:26:22,257:jax._src.xla_bridge:924: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2025-10-27 10:26:22,273:jax._src.xla_bridge:924: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory

# %%
num_epochs = 100
batch_size = 16

history = model.fit(
    x_train, y_train,
    validation_split=0.2,
    epochs=num_epochs,
    batch_size=batch_size,
)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.0711 - mean_absolute_error: 1.7067 - val_loss: 1.1008 - val_mean_absolute_error: 0.7870
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2923 - mean_absolute_error: 0.8381 - val_loss: 0.6998 - val_mean_absolute_error: 0.6502
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8373 - mean_absolute_error: 0.6854 - val_loss: 0.5585 - val_mean_absolute_error: 0.5832
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6053 - mean_absolute_error: 0.5928 - val_loss: 0.4935 - val_mean_absolute_error: 0.5395
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4969 - mean_absolute_error: 0.5465 - val_loss: 0.5020 - val_mean_absolute_error: 0.5222
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3884 - mean_absolute_error: 0.4703 - val_loss: 0.4484 - val_mean_absolute_error: 0.4926
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3717 - mean_absolute_error: 0.4637 - val_loss: 0.4357 - val_mean_absolute_error: 0.4813
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3340 - mean_absolute_error: 0.4289 - val_loss: 0.4205 - val_mean_absolute_error: 0.4686
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2948 - mean_absolute_error: 0.4086 - val_loss: 0.4008 - val_mean_absolute_error: 0.4605
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3128 - mean_absolute_error: 0.4067 - val_loss: 0.3911 - val_mean_absolute_error: 0.4451
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2838 - mean_absolute_error: 0.3910 - val_loss: 0.3910 - val_mean_absolute_error: 0.4472
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2427 - mean_absolute_error: 0.3618 - val_loss: 0.3700 - val_mean_absolute_error: 0.4339
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2804 - mean_absolute_error: 0.3926 - val_loss: 0.3307 - val_mean_absolute_error: 0.4052
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2208 - mean_absolute_error: 0.3406 - val_loss: 0.3430 - val_mean_absolute_error: 0.4105
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2366 - mean_absolute_error: 0.3645 - val_loss: 0.3193 - val_mean_absolute_error: 0.3951
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2659 - mean_absolute_error: 0.3586 - val_loss: 0.3517 - val_mean_absolute_error: 0.4056
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1923 - mean_absolute_error: 0.3032 - val_loss: 0.3152 - val_mean_absolute_error: 0.3915
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2021 - mean_absolute_error: 0.3248 - val_loss: 0.3369 - val_mean_absolute_error: 0.3892
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1399 - mean_absolute_error: 0.2769 - val_loss: 0.3052 - val_mean_absolute_error: 0.3733
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1456 - mean_absolute_error: 0.2737 - val_loss: 0.3069 - val_mean_absolute_error: 0.3711
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1871 - mean_absolute_error: 0.2937 - val_loss: 0.3005 - val_mean_absolute_error: 0.3650
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1608 - mean_absolute_error: 0.2795 - val_loss: 0.3082 - val_mean_absolute_error: 0.3643
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1602 - mean_absolute_error: 0.2774 - val_loss: 0.2862 - val_mean_absolute_error: 0.3498
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1239 - mean_absolute_error: 0.2502 - val_loss: 0.3138 - val_mean_absolute_error: 0.3569
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1202 - mean_absolute_error: 0.2522 - val_loss: 0.2847 - val_mean_absolute_error: 0.3374
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1324 - mean_absolute_error: 0.2499 - val_loss: 0.2883 - val_mean_absolute_error: 0.3343
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1452 - mean_absolute_error: 0.2557 - val_loss: 0.2963 - val_mean_absolute_error: 0.3379
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1150 - mean_absolute_error: 0.2282 - val_loss: 0.3001 - val_mean_absolute_error: 0.3354
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1211 - mean_absolute_error: 0.2322 - val_loss: 0.2890 - val_mean_absolute_error: 0.3292
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1045 - mean_absolute_error: 0.2277 - val_loss: 0.3198 - val_mean_absolute_error: 0.3419
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1016 - mean_absolute_error: 0.2243 - val_loss: 0.2830 - val_mean_absolute_error: 0.3208
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0931 - mean_absolute_error: 0.2100 - val_loss: 0.2827 - val_mean_absolute_error: 0.3241
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0868 - mean_absolute_error: 0.2121 - val_loss: 0.2876 - val_mean_absolute_error: 0.3299
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1102 - mean_absolute_error: 0.2336 - val_loss: 0.3127 - val_mean_absolute_error: 0.3268
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0928 - mean_absolute_error: 0.2167 - val_loss: 0.2764 - val_mean_absolute_error: 0.3088
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0715 - mean_absolute_error: 0.1942 - val_loss: 0.2803 - val_mean_absolute_error: 0.3084
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0783 - mean_absolute_error: 0.2019 - val_loss: 0.2863 - val_mean_absolute_error: 0.3079
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0790 - mean_absolute_error: 0.2038 - val_loss: 0.2801 - val_mean_absolute_error: 0.3093
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0812 - mean_absolute_error: 0.2058 - val_loss: 0.3041 - val_mean_absolute_error: 0.3178
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0853 - mean_absolute_error: 0.2065 - val_loss: 0.2749 - val_mean_absolute_error: 0.3083
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0850 - mean_absolute_error: 0.1993 - val_loss: 0.2694 - val_mean_absolute_error: 0.2932
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0842 - mean_absolute_error: 0.2025 - val_loss: 0.3092 - val_mean_absolute_error: 0.3186
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0796 - mean_absolute_error: 0.1988 - val_loss: 0.2449 - val_mean_absolute_error: 0.2779
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0799 - mean_absolute_error: 0.1897 - val_loss: 0.2888 - val_mean_absolute_error: 0.3106
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0671 - mean_absolute_error: 0.1911 - val_loss: 0.2659 - val_mean_absolute_error: 0.2962
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0752 - mean_absolute_error: 0.1902 - val_loss: 0.3264 - val_mean_absolute_error: 0.3189
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0864 - mean_absolute_error: 0.1991 - val_loss: 0.2918 - val_mean_absolute_error: 0.3058
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0785 - mean_absolute_error: 0.2026 - val_loss: 0.2712 - val_mean_absolute_error: 0.3029
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0695 - mean_absolute_error: 0.1840 - val_loss: 0.2918 - val_mean_absolute_error: 0.3037
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0635 - mean_absolute_error: 0.1825 - val_loss: 0.2725 - val_mean_absolute_error: 0.2943
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0631 - mean_absolute_error: 0.1776 - val_loss: 0.2716 - val_mean_absolute_error: 0.2945
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0606 - mean_absolute_error: 0.1696 - val_loss: 0.2605 - val_mean_absolute_error: 0.2883
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0634 - mean_absolute_error: 0.1780 - val_loss: 0.2599 - val_mean_absolute_error: 0.2896
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - mean_absolute_error: 0.1756 - val_loss: 0.2653 - val_mean_absolute_error: 0.2986
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0618 - mean_absolute_error: 0.1826 - val_loss: 0.2690 - val_mean_absolute_error: 0.3018
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0743 - mean_absolute_error: 0.2016 - val_loss: 0.2608 - val_mean_absolute_error: 0.2928
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0594 - mean_absolute_error: 0.1777 - val_loss: 0.3011 - val_mean_absolute_error: 0.3124
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0591 - mean_absolute_error: 0.1840 - val_loss: 0.2619 - val_mean_absolute_error: 0.2896
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - mean_absolute_error: 0.1613 - val_loss: 0.2642 - val_mean_absolute_error: 0.2882
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0624 - mean_absolute_error: 0.1770 - val_loss: 0.2766 - val_mean_absolute_error: 0.3086
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0620 - mean_absolute_error: 0.1846 - val_loss: 0.2620 - val_mean_absolute_error: 0.2904
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0687 - mean_absolute_error: 0.1830 - val_loss: 0.2661 - val_mean_absolute_error: 0.3016
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mean_absolute_error: 0.1690 - val_loss: 0.2602 - val_mean_absolute_error: 0.2929
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0598 - mean_absolute_error: 0.1725 - val_loss: 0.2604 - val_mean_absolute_error: 0.2921
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mean_absolute_error: 0.1634 - val_loss: 0.2535 - val_mean_absolute_error: 0.2894
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0579 - mean_absolute_error: 0.1706 - val_loss: 0.2661 - val_mean_absolute_error: 0.2931
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555 - mean_absolute_error: 0.1700 - val_loss: 0.2707 - val_mean_absolute_error: 0.2934
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0480 - mean_absolute_error: 0.1607 - val_loss: 0.2634 - val_mean_absolute_error: 0.2896
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493 - mean_absolute_error: 0.1600 - val_loss: 0.2598 - val_mean_absolute_error: 0.2926
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0505 - mean_absolute_error: 0.1681 - val_loss: 0.2621 - val_mean_absolute_error: 0.2881
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mean_absolute_error: 0.1707 - val_loss: 0.2826 - val_mean_absolute_error: 0.3004
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0507 - mean_absolute_error: 0.1697 - val_loss: 0.2750 - val_mean_absolute_error: 0.3037
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0607 - mean_absolute_error: 0.1742 - val_loss: 0.2876 - val_mean_absolute_error: 0.3033
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mean_absolute_error: 0.1741 - val_loss: 0.2558 - val_mean_absolute_error: 0.2855
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0511 - mean_absolute_error: 0.1655 - val_loss: 0.2770 - val_mean_absolute_error: 0.2978
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0578 - mean_absolute_error: 0.1726 - val_loss: 0.2558 - val_mean_absolute_error: 0.2858
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0494 - mean_absolute_error: 0.1527 - val_loss: 0.2472 - val_mean_absolute_error: 0.2942
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0596 - mean_absolute_error: 0.1764 - val_loss: 0.2871 - val_mean_absolute_error: 0.3128
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.1560 - val_loss: 0.2671 - val_mean_absolute_error: 0.2924
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mean_absolute_error: 0.1579 - val_loss: 0.2533 - val_mean_absolute_error: 0.2909
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - mean_absolute_error: 0.1629 - val_loss: 0.2699 - val_mean_absolute_error: 0.3002
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0449 - mean_absolute_error: 0.1581 - val_loss: 0.2573 - val_mean_absolute_error: 0.2913
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0463 - mean_absolute_error: 0.1544 - val_loss: 0.2935 - val_mean_absolute_error: 0.3087
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - mean_absolute_error: 0.1652 - val_loss: 0.2382 - val_mean_absolute_error: 0.2903
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0420 - mean_absolute_error: 0.1460 - val_loss: 0.2640 - val_mean_absolute_error: 0.2987
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0441 - mean_absolute_error: 0.1533 - val_loss: 0.2622 - val_mean_absolute_error: 0.3023
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0559 - mean_absolute_error: 0.1721 - val_loss: 0.2502 - val_mean_absolute_error: 0.2877
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - mean_absolute_error: 0.1536 - val_loss: 0.2760 - val_mean_absolute_error: 0.3188
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460 - mean_absolute_error: 0.1617 - val_loss: 0.2563 - val_mean_absolute_error: 0.3091
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0418 - mean_absolute_error: 0.1537 - val_loss: 0.2548 - val_mean_absolute_error: 0.2924
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379 - mean_absolute_error: 0.1432 - val_loss: 0.2355 - val_mean_absolute_error: 0.2840
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - mean_absolute_error: 0.1589 - val_loss: 0.2627 - val_mean_absolute_error: 0.2967
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - mean_absolute_error: 0.1516 - val_loss: 0.2369 - val_mean_absolute_error: 0.2851
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0441 - mean_absolute_error: 0.1507 - val_loss: 0.3112 - val_mean_absolute_error: 0.3187
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0432 - mean_absolute_error: 0.1574 - val_loss: 0.2448 - val_mean_absolute_error: 0.2985
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0558 - mean_absolute_error: 0.1883 - val_loss: 0.2743 - val_mean_absolute_error: 0.3042
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - mean_absolute_error: 0.1547 - val_loss: 0.2464 - val_mean_absolute_error: 0.2923
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - mean_absolute_error: 0.1572 - val_loss: 0.2840 - val_mean_absolute_error: 0.3060
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0432 - mean_absolute_error: 0.1486 - val_loss: 0.2601 - val_mean_absolute_error: 0.2988
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0335 - mean_absolute_error: 0.1343 - val_loss: 0.2452 - val_mean_absolute_error: 0.2974

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (16, 64)               │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (16, 64)               │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (16, 1)                │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,405 (56.27 KB)
#  Trainable params: 4,801 (18.75 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 9,604 (37.52 KB)
