# %%
#====================================================================================================#
#                                                                                                    #
#                                                        ██╗   ██╗   ████████╗ █████╗ ██████╗        #
#      Modelo NLP - Clasificación de Textos             ██║   ██║   ╚══██╔══╝██╔══██╗██╔══██╗       #
#                                                        ██║   ██║█████╗██║   ███████║██║  ██║       #
#      created:        07/02/2026  -  09:00:00           ██║   ██║╚════╝██║   ██╔══██║██║  ██║       #
#      last change:    07/02/2026  -  09:00:00           ╚██████╔╝      ██║   ██║  ██║██████╔╝       #
#                                                         ╚═════╝       ╚═╝   ╚═╝  ╚═╝╚═════╝        #
#                                                                                                    #
#      Ismael Hernandez Clemente                         ismael.hernandez@live.u-tad.com             #
#                                                                                                    #
#      Github:                                           https://github.com/ismaelucky342            #
#                                                                                                    #
#====================================================================================================#

# %% [markdown]
# # Clasificador de Textos - NLP Básico

# %% [markdown]
# ## 1. Librerías e importaciones

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

np.random.seed(42)

# %% [markdown]
# ## 2. Carga de datos

# %%
# Dataset IMDB: clasificación de sentimientos (positivo/negativo)
vocab_size = 10000  # Vocabulario: 10k palabras más frecuentes

(x_train, y_train), (x_test, y_test) = keras.datasets.imdb.load_data(num_words=vocab_size)

print(f"Train: {len(x_train)}, Test: {len(x_test)}")

# %% [markdown]
# ## 3. Preprocesamiento (Padding)

# %%
# Padding: todas las secuencias a la misma longitud
max_length = 200

x_train = pad_sequences(x_train, maxlen=max_length)
x_test = pad_sequences(x_test, maxlen=max_length)

print(f"Shape después padding: {x_train.shape}")

# %% [markdown]
# ## 4. Modelo

# %%
model = keras.Sequential([
    # Embedding: convierte palabras a vectores
    layers.Embedding(vocab_size, 128),
    
    # GlobalAveragePooling: promedia todos los embeddings
    layers.GlobalAveragePooling1D(),
    
    # Dense layers
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')  # Salida binaria
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# %% [markdown]
# ## 5. Entrenamiento

# %%
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=512,
    validation_split=0.2
)

# %% [markdown]
# ## 6. Evaluación

# %%
# Curvas
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss')
plt.legend()

plt.show()

# Test
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Accuracy: {test_acc:.4f}")
