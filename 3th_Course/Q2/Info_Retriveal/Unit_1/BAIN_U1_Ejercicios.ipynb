# %%
# !pip install ipython-autotime fastavro
# %load_ext autotime

# %% [markdown]
# # Funciones & comprehension

# %% [markdown]
# Compara el rendimiento de ejecutar el mismo código usando `for` o list comprehension. Prueba a subir el valor de N.

# %%
numbers = []

N = 10**6

for i in range(N):
    numbers.append(i*2)

# %%
N = 10**6

numbers = [i*2 for i in range(N)]

numbers

# %%
N = 100

numbers

# %%
def function(N):
  return [i*2 for i in range(N)]

# %%
numbers_2 = function(100)

# %%
numbers_2

# %% [markdown]
# Completa el código siguiente según las instrucciones.

# %%
# Ejercicio
def alumnos_aprobados(estudiantes):
  try:
    # Rellena aquí tu código, ¿será más eficiente con list comprehension?
    # Genera una lista de alumnos aprobados, con nota mayor o igual a 5
    return
  except Exception as e:
    print(f"An error occurred: {e}")
    return

estudiantes = [
    {"nombre": "Ana", "nota": 7},
    {"nombre": "Luis", "nota": 4},
    {"nombre": "Carlos", "nota": 9},
    {"nombre": "Marta", "nota": 6}
]

alumnos_aprobados(estudiantes)

# %% [markdown]
# Usar la función `es_primo`para generar una diccionario que contenga como clave los números del 1 al 100 y como valor un booleano indicando si es primo o no.

# %%
def es_primo(n):
    return not any( (n % d == 0 for d in range(2, n // 2 + 1)) )

# %%
# Ejercicio

numeros_primos = {x: es_primo(x) for x in range(1, 101) if x % 2 == 0}

numeros_primos

# %% [markdown]
# Crea una función llamada `es_divisible` que reciba dos argumentos, `x` e `y`, e indique si `x` es divisible por `y` o no (debe devolver un booleano).
#
# Comprueba si `7893209` es divisible por 9. ¿Y por 23?

# %%
def es_divisible(x,y):

# %% [markdown]
# ¿Qué pasa si dividimos entre 0? ¿Cómo lo resolverías?

# %%
##

# %% [markdown]
# Genera una función que devuelva el cuadrado de los números de un valor inicial a uno final (incluido) usando list comprehension

# %%
# Ejercicio

# %% [markdown]
# # Pandas & Polars

# %%
# Ejercicio: Completa el código siguiente según las instrucciones.
import pandas as pd
from fastavro import writer, parse_schema

# Supongamos que contamos con un archivo CSV con datos de ventas.
# El CSV contiene columnas: fecha, categoria y valor.

# Guardar el DataFrame en formato CSV.

# Guardar el DataFrame en formato JSON.


# Guardar el DataFrame en formato Parquet.


# Guardar el DataFrame en formato Avro.
# Definimos un esquema para los datos.
schema = {
    "doc": "Datos de ventas",
    "name": "Venta",
    "namespace": "analisis.ventas",
    "type": "record",
    "fields": [
        {"name": "fecha", "type": "string"},
        {"name": "categoria", "type": "string"},
        {"name": "valor", "type": "float"}
    ]
}
# Rellena aquí tu código
schema_parsed = parse_schema(schema)
 ## convertir a un diccionario nuestro df
 ## abrir un archivo de tipo avro (permisos "wb")
 ### escribir uusando el writer de fastavro

# %%
# Ejercicio: Completa el código siguiente según las instrucciones.
from os import path
import polars as pl

# Supongamos que contamos con un archivo CSV con datos de ventas.
# El CSV contiene columnas: fecha, categoria y valor.

# Guardar el DataFrame en formato CSV.

# Guardar el DataFrame en formato JSON.

# Guardar el DataFrame en formato Parquet.

# Guardar el DataFrame en formato Avro.
# Definimos un esquema para los datos.
schema = {
    "doc": "Datos de ventas",
    "name": "Venta",
    "namespace": "analisis.ventas",
    "type": "record",
    "fields": [
        {"name": "fecha", "type": "string"},
        {"name": "categoria", "type": "string"},
        {"name": "valor", "type": "float"}
    ]
}

# Rellena aquí tu código

## df.write_avro("data.avro")

# %% [markdown]
# ## Leer avro pandas

# %%
# Ejercicio: Leer y printear un archivo avro con pandas
from fastavro import reader
import pandas as pd

# Rellena aquí tu código

# %% [markdown]
# ## Leer avro Polars

# %%
# Ejercicio: Leer y printear un archivo avro con polars

# %% [markdown]
# ## Operaciones pandas & polars

# %%
# Ejercicio: Completa el código siguiente según las instrucciones.
import pandas as pd
import polars as pl
print("####### Pandas ######")

# Cargar datos de un archivo CSV con Pandas.

# Realizar una transformación en Pandas:
# Filtrar ventas con un valor mayor a 100 y calcular el promedio de ventas por categoría.

print("####### Polars ######")

# Cargar datos de un archivo CSV con Polars.

# Realizar una transformación en Polars:
# Filtrar ventas con un valor mayor a 100 y calcular el promedio de ventas por categoría.

# %% [markdown]
# ## Aplicar funciones pandas & polars

# %%
# Ejercicio: Aplica una función a cada fila para crear una nueva columna llamada "price_range".
# Esta columna debe indicar "expensive" si el valor es mayor a 75 y "cheap" en cualquier otro caso
# Finalmente devuelve el dataframe resultante
import pandas as pd
import polars as pl


# Definir función auxiliar
def check_expensive(value):
  return
