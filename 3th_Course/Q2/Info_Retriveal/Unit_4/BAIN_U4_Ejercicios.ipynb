# %% [markdown]
# # Ejercicio 1: LDA con gensim
# - Preprocesa un corpus (archivo "text_mining.txt") aplicando tokenización, eliminación de stopwords y lematización.
# - Crea el diccionario y el corpus bag-of-words.
# - Entrena un modelo LDA extrayendo 2 o 3 tópicos y muestra la distribución de tópicos para cada documento.

# %%
# Ejemplo de contenido de text_mining.text

text = """
La ciencia e ingeniería de datos con Python es un campo en crecimiento
En la UTad estoy aprendiendo sobre ellos mediante Python
Me encanta leer sobre la ingeniería de datos con Python
La inteligencia artificial está evolucionando rápidamente en la ciencia de datos
Python se utiliza en el análisis de datos y la ingeniería de datos
"""

# %% [markdown]
# # Ejercicio 2: Análisis de Sentimiento con TextBlob
# - Crea un archivo "comments.csv" con comentarios (al menos 10).
# - Utiliza TextBlob para calcular la polaridad y subjetividad de cada comentario.
# - Filtra y muestra los comentarios con polaridad menor a -0.3.

# %% [markdown]
# Ejemplo de contenido de comments.csv
#
# |id |text                                                     |
# |---|---------------------------------------------------------|
# |1  |This product is literally trash. Do not waste your money.|
# |2  |Cool, another app that crashes every 5 minutes. Love it! |
# |3  |Not the worst purchase I've made, but close.             |
# |4  |The features are sick, but the battery dies in an hour.  |
# |5  |I’m thrilled to have my data sold without consent!       |
# |6  |It’s okay, I guess. If you enjoy disappointment.         |
# |7  |Fantastic! Said no one ever about this junk.             |
# |8  |Works as intended... if you intend to frustrate users.   |
# |9  |A masterpiece of poor design. Truly innovative!          |
# |10 |Not bad, if you ignore the fact that it broke instantly. |
# |11 |Perfect for people who hate reliability.                 |
# |12 |Wow, just what I needed... another useless gadget!       |
# |13 |The quality is fire! (Literally, it overheats.)          |
# |14 |10/10 would NOT recommend to my worst enemy.             |
# |15 |Great, if you define ‘great’ as ‘barely functional’.     |
# |16 |This is the worst thing since sliced bread.              |
# |17 |Impressive how they made something so mediocre.          |
# |18 |It’s fine. If fine means ‘I want a refund’.              |
# |19 |Unbelievable! (In the worst way possible.)               |
# |20 |Five stars... for being a doorstop, not a device.        |

# %% [markdown]
# # Ejercicio 3: Parsing de Documentos
# - Usando NLTK, realiza el parsing de constituyentes en una oración compleja y dibuja el árbol.
# - Con spaCy, muestra el dependency parsing de la misma oración.

# %%
# Ejemplo de oración para utilizar:

sentence = "John sees Mary with a telescope."

# %% [markdown]
# # Ejercicio 4: Resumen Automático Extractivo
# - A partir de un texto largo, segmenta en oraciones y calcula un score basado en la frecuencia de palabras (puedes usar el método mostrado en el ejemplo).
# - Selecciona las oraciones con mayor score para generar un resumen.

# %%
# Texto 
text = """
El procesamiento del lenguaje natural (PLN) es una disciplina en rápido crecimiento que integra lingüística, informática y estadística para interpretar el lenguaje humano. En los últimos años, las técnicas basadas en aprendizaje profundo han revolucionado el campo, permitiendo a las máquinas realizar tareas complejas como la traducción automática, el análisis de sentimientos y el resumen de textos. A pesar de estos avances, los desafíos persisten, especialmente en la interpretación de contextos ambiguos y la detección de ironías o sarcasmo en el discurso.

Las aplicaciones del PLN son numerosas y variadas: desde asistentes virtuales que responden preguntas en lenguaje natural hasta sistemas de recomendación que analizan opiniones de usuarios en redes sociales. Además, la disponibilidad de grandes volúmenes de datos textuales ha impulsado la creación de modelos estadísticos que permiten descubrir temas latentes en documentos extensos y evaluar la coherencia de los tópicos generados.

Sin embargo, es fundamental acompañar estas técnicas de métodos de preprocesamiento adecuados, tales como la tokenización, la normalización y la eliminación de palabras vacías. Solo mediante un pipeline integral se pueden extraer conclusiones precisas y útiles de los datos textuales. De cara al futuro, la combinación de métodos tradicionales y enfoques basados en modelos de lenguaje avanzados promete transformar la manera en que interactuamos con la información, mejorando tanto la eficiencia como la calidad de las soluciones implementadas.
"""
